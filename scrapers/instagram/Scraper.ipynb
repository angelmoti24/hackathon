# %% [markdown]
# # Instagram Scraping

# %%
from pprint import pprint
import pandas as pd
import numpy as np
#import fasttext
import subprocess
import time
from pathlib import Path
import os

# %% [markdown]
# ## Scrap the account posts

# %% [markdown]
# ### Run the following commands to install InstaTouch and scrape the data
#
# ```bash
# $ npm i instatouch
# $
# $ mkdir -p "$(pwd)"/dataset/bbva_mex && \
# $ mkdir -p "$(pwd)"/dataset/yosoypyme && \
# $ mkdir -p "$(pwd)"/dataset/bbva_seguros && \
# $ mkdir -p "$(pwd)"/dataset/bbvauy && \
# $ mkdir -p "$(pwd)"/dataset/bbva_peru && \
# $ mkdir -p "$(pwd)"/dataset/fundacionbbvape && \
# $ mkdir -p "$(pwd)"/dataset/bbva && \
# $ mkdir -p "$(pwd)"/dataset/bbvaprovincial && \
# $ mkdir -p "$(pwd)"/dataset/bbva_colombia && \
# $ mkdir -p "$(pwd)"/dataset/bbvaamcolombia && \
# $ mkdir -p "$(pwd)"/dataset/bbva_argentina
# $
# $ instatouch user bbva_mex -c 1000 --filepath "$(pwd)"/dataset/bbva_mex && \
# $ instatouch user yosoypyme -c 1000 --filepath "$(pwd)"/dataset/yosoypyme && \
# $ instatouch user bbva_seguros -c 1000 --filepath "$(pwd)"/dataset/bbva_seguros && \
# $ instatouch user bbvauy -c 1000 --filepath "$(pwd)"/dataset/bbvauy && \
# $ instatouch user bbva_peru -c 1000 --filepath "$(pwd)"/dataset/bbva_peru && \
# $ instatouch user fundacionbbvape -c 1000 --filepath "$(pwd)"/dataset/fundacionbbvape && \
# $ instatouch user bbva -c 1000 --filepath "$(pwd)"/dataset/bbva && \
# $ instatouch user bbvaprovincial -c 1000 --filepath "$(pwd)"/dataset/bbvaprovincial && \
# $ instatouch user bbva_colombia -c 1000 --filepath "$(pwd)"/dataset/bbva_colombia && \
# $ instatouch user bbvaamcolombia -c 1000 --filepath "$(pwd)"/dataset/bbvaamcolombia && \
# $ instatouch user bbva_argentina -c 1000 --filepath "$(pwd)"/dataset/bbva_argentina
# ```

# %% [markdown]
# ## Check the data

# %%
accounts = ["bbva_mex", "yosoypyme", "bbva_seguros", "bbvauy", "bbva_peru", "fundacionbbvape", "bbva", "bbvaprovincial", "bbva_colombia", "bbvaamcolombia", "bbva_argentina"]
#countries = ["mex", "ar", "pe", "col", "uy", "es", "ve", "col"]
account = accounts[0]
#country = countries[0]
csv_name = list(filter(lambda x: '.csv' in x, os.listdir(f'./dataset/{account}/')))[0]
ig_bbva_posts = pd.read_csv(f'./dataset//{account}/{csv_name}')

# %%
ig_bbva_posts.head(4)
# Out:
#                     id    shortcode          type  is_video  dimension.height  \
# 0  2421504519680313931  CGa6YftjEpL  GraphSidecar     False              1080
# 1  2420053243746800524  CGVwZprD1OM    GraphImage     False               720
# 2  2415614438164888545  CGF_Ih1H3vh    GraphImage     False              1350
# 3  2414299946008063669  CGBUQJnDi61  GraphSidecar     False              1080
#
#    dimension.width                                        display_url  \
# 0             1080  https://instagram.fmex16-1.fna.fbcdn.net/v/t51...
# 1             1080  https://instagram.fmex16-1.fna.fbcdn.net/v/t51...
# 2             1080  https://instagram.fmex16-1.fna.fbcdn.net/v/t51...
# 3             1080  https://instagram.fmex16-1.fna.fbcdn.net/v/t51...
#
#                                        thumbnail_src   owner.id  \
# 0  https://instagram.fmex16-1.fna.fbcdn.net/v/t51...  336339103
# 1  https://instagram.fmex16-1.fna.fbcdn.net/v/t51...  336339103
# 2  https://instagram.fmex16-1.fna.fbcdn.net/v/t51...  336339103
# 3  https://instagram.fmex16-1.fna.fbcdn.net/v/t51...  336339103
#
#   owner.username  ... comments_disabled  taken_at_timestamp  location  \
# 0       bbva_mex  ...             False          1602885855       NaN
# 1       bbva_mex  ...             False          1602712849       NaN
# 2       bbva_mex  ...             False          1602183702       NaN
# 3       bbva_mex  ...             False          1602027003       NaN
#
#                                             hashtags               mentions  \
# 0                             ["#TorreBBVA","#CDMX"]                     []
# 1        ["#BBVAM","#CreandoOportunidades","#Metas"]                     []
# 2  ["#TorreBBVA","#BBVAMe","#CDMX","#Di","#Nublado"]          ["@vrtypics"]
# 3  ["#BBVAM","#CreandoOportunidades","#ProgramaBB...  ["@museocarrillogil"]
#
#    views location.id location.has_public_page  location.name  location.slug
# 0    NaN         NaN                      NaN            NaN            NaN
# 1    NaN         NaN                      NaN            NaN            NaN
# 2    NaN         NaN                      NaN            NaN            NaN
# 3    NaN         NaN                      NaN            NaN            NaN
#
# [4 rows x 23 columns]

# %%
ig_bbva_posts.count()
# Out:
# id                          52
# shortcode                   52
# type                        52
# is_video                    52
# dimension.height            52
# dimension.width             52
# display_url                 52
# thumbnail_src               52
# owner.id                    52
# owner.username              52
# description                 52
# comments                    52
# likes                       52
# comments_disabled           52
# taken_at_timestamp          52
# location                     0
# hashtags                    52
# mentions                    52
# views                       12
# location.id                  1
# location.has_public_page     1
# location.name                1
# location.slug                1
# dtype: int64

# %% [markdown]
# ## Scrap post comments and likers

# %%
accounts = ["yosoypyme", "bbva_seguros", "bbvauy", "bbva_peru", "fundacionbbvape", "bbva", "bbvaprovincial", "bbva_colombia", "bbvaamcolombia", "bbva_argentina"]

def scrape_comments(short_code, account):
    Path(f"./dataset/{account}/comments").mkdir(parents=True, exist_ok=True)
    proc = subprocess.Popen(
        [
            "../node_modules/instatouch/bin/cli.js",
            "comments",
            f"https://instagram.com/p/{short_code}",
            "--filepath",
            f"./dataset/{account}/comments/",
        #    "--proxy-file",
        #    "./proxies.txt"
        ],
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE
    )
    out, err = proc.communicate()
    print(f"[STDERR] {err}")
    print(f"[STDOUT] {out}")

def scrape_likers(short_code, account):
    Path(f"./dataset/{account}/likers").mkdir(parents=True, exist_ok=True)
    proc = subprocess.Popen(
        [
            "../node_modules/instatouch/bin/cli.js",
            "likers",
            f"https://instagram.com/p/{short_code}",
            "--filepath",
            f"./dataset/{account}/likers/",
        #    "--proxy-file",
        #    "./proxies.txt"
        ],
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE
    )
    out, err = proc.communicate()
    print(f"[STDERR] {err}")
    print(f"[STDOUT] {out}")

for account in accounts:
    csv_name = list(filter(lambda x: '.csv' in x, os.listdir(f'./dataset/{account}/')))[0]
    ig_bbva_posts = pd.read_csv(f'./dataset/{account}/{csv_name}')
    for short_code in ig_bbva_posts['shortcode']:
        print(f"Scraping data for: {short_code}")
        scrape_comments(short_code, account)
        time.sleep(3)
        scrape_likers(short_code, account)
        time.sleep(3)
    print(f"[SCRAPED] {account}")
# Out:
# rted\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/comments//comments_1602923635458.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/likers//likers_1602923639162.csv\n'
# Scraping data for: CAnhzhBH2I4
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/comments//comments_1602923642783.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/likers//likers_1602923646383.csv\n'
# Scraping data for: CAbYioSHoyI
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/comments//comments_1602923650011.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/likers//likers_1602923653699.csv\n'
# Scraping data for: CAfrHziHHcz
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/comments//comments_1602923657332.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/likers//likers_1602923661100.csv\n'
# Scraping data for: CAvrzOels1i
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b''
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/likers//likers_1602923668553.csv\n'
# Scraping data for: B_Qp4LSDqvo
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/comments//comments_1602923672338.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/likers//likers_1602923676071.csv\n'
# Scraping data for: B_GUJ2YH-QF
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b''
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/likers//likers_1602923683474.csv\n'
# Scraping data for: CADXy3Ynm0t
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/comments//comments_1602923687179.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/likers//likers_1602923690850.csv\n'
# Scraping data for: B-uybNGjQUF
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/comments//comments_1602923694459.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/likers//likers_1602923698152.csv\n'
# Scraping data for: B-scRgxn2Zy
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/comments//comments_1602923701740.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/likers//likers_1602923706059.csv\n'
# Scraping data for: B-X_Xh3H0N3
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/comments//comments_1602923709716.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/likers//likers_1602923713377.csv\n'
# Scraping data for: B-P-whFHVwf
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/comments//comments_1602923717251.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/likers//likers_1602923721551.csv\n'
# Scraping data for: B-NP1NoHUoJ
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/comments//comments_1602923725369.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/likers//likers_1602923729179.csv\n'
# Scraping data for: B-KezVfnX1l
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b''
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/likers//likers_1602923736554.csv\n'
# Scraping data for: B_yO4cVniXD
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/comments//comments_1602923740536.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/likers//likers_1602923744523.csv\n'
# Scraping data for: B_TCevYHqkG
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/comments//comments_1602923748223.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/likers//likers_1602923751876.csv\n'
# Scraping data for: B_sUXwnHyVT
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/comments//comments_1602923755501.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/likers//likers_1602923759192.csv\n'
# Scraping data for: B-DEJ_DnyjW
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/comments//comments_1602923763023.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/likers//likers_1602923766747.csv\n'
# Scraping data for: B_A6fAznX5o
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/comments//comments_1602923770406.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbvaamcolombia/likers//likers_1602923774072.csv\n'
# [SCRAPED] bbvaamcolombia
# Scraping data for: CGAY-zhjueX
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923777800.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923781469.csv\n'
# Scraping data for: CF1_470g6fi
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923785285.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923789017.csv\n'
# Scraping data for: CGS-gqXAgDW
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923792665.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923796402.csv\n'
# Scraping data for: CGU1ufTht0t
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923800410.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923804106.csv\n'
# Scraping data for: CFzbEAJn_C-
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923807911.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923811609.csv\n'
# Scraping data for: CGH9-rDgi-x
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923815579.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923819279.csv\n'
# Scraping data for: CGC4ZJ0hCeN
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923823471.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923827333.csv\n'
# Scraping data for: CFPX7UglAB9
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923831293.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923834964.csv\n'
# Scraping data for: CFcP7i5lEeK
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923838731.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923842426.csv\n'
# Scraping data for: CFxFWaVF5LP
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923846327.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923850079.csv\n'
# Scraping data for: CFuvIafFgUw
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923853840.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923857541.csv\n'
# Scraping data for: CFsUqYsFxif
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923861278.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923864921.csv\n'
# Scraping data for: CE4ULkThuWu
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923868696.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923872364.csv\n'
# Scraping data for: CFKS8XgFb9q
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923876130.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923879778.csv\n'
# Scraping data for: CFIfZrDBB_f
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923883530.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923887205.csv\n'
# Scraping data for: CEt5qL8gJEy
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923891005.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923894681.csv\n'
# Scraping data for: CEmy3MUlqs1
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923898623.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923902375.csv\n'
# Scraping data for: CDwIKtRA0kD
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923906239.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923909937.csv\n'
# Scraping data for: CDg5kfSl56w
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923913682.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923917413.csv\n'
# Scraping data for: CEE4cUXBwwZ
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923921197.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923924879.csv\n'
# Scraping data for: CDMsTEcl08E
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923928710.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923932364.csv\n'
# Scraping data for: CC6JbdWly-M
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923936143.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923939848.csv\n'
# Scraping data for: CCoIgDSD7if
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923943619.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923947316.csv\n'
# Scraping data for: CClr4BJha_N
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923951045.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923954905.csv\n'
# Scraping data for: CEURfExhjZE
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923958740.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923962438.csv\n'
# Scraping data for: CCWizU0lEW_
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923966329.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923970069.csv\n'
# Scraping data for: CCJDGsWpcBG
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923973844.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923977605.csv\n'
# Scraping data for: CCEm6xjlj72
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923981411.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923985191.csv\n'
# Scraping data for: CByFKMYgXyB
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923989037.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602923992770.csv\n'
# Scraping data for: CBjycYWFEIY
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602923996696.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924000393.csv\n'
# Scraping data for: CBgj_JkDGAh
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924004151.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924007810.csv\n'
# Scraping data for: CEC7pmlDoWl
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924011527.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924015182.csv\n'
# Scraping data for: CBOaUuCHnbZ
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924018965.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924022632.csv\n'
# Scraping data for: CA726PvF8zG
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924026452.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924030102.csv\n'
# Scraping data for: CAp8GSIg_Rc
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924033862.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924037583.csv\n'
# Scraping data for: CAXzxWKg23W
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924041335.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924045012.csv\n'
# Scraping data for: CAFyTHrlD_r
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924048741.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924052441.csv\n'
# Scraping data for: CDca5hfApWb
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924056179.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924059854.csv\n'
# Scraping data for: B_8bARHDRsi
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924063653.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924067359.csv\n'
# Scraping data for: B_zybDggUSB
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924071163.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924074845.csv\n'
# Scraping data for: B_hvLc3jE26
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924078549.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924082234.csv\n'
# Scraping data for: CEReFUdF2VL
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924085974.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924089650.csv\n'
# Scraping data for: B_PtnoqlJ1M
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924093417.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924097613.csv\n'
# Scraping data for: B_IBHqrjTRd
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924101454.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924105155.csv\n'
# Scraping data for: B_A-lYnDdmj
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924109043.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924112784.csv\n'
# Scraping data for: B-9r6arl85m
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924116590.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924120305.csv\n'
# Scraping data for: B-zgGYmDDQH
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924124274.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924128014.csv\n'
# Scraping data for: CBWOnoKjQwX
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924131881.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924135619.csv\n'
# Scraping data for: B_S0qIsAPzJ
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924139430.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924143062.csv\n'
# Scraping data for: CCZbg9JAwkX
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924146863.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924150524.csv\n'
# Scraping data for: B-rxdrYDFMk
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924154271.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924158047.csv\n'
# Scraping data for: CAEL2RNDEQu
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/comments//comments_1602924162034.csv\n'
# [STDERR] b'- InstaTouch Scraper Started\n'
# [STDOUT] b'CSV path: ./dataset/bbva_argentina/likers//likers_1602924165814.csv\n'
# [SCRAPED] bbva_argentina

# %% [markdown]
# ## Join the csv comments

# %%
i = 0
for account in accounts:
    for csv_name in os.listdir(f'dataset/{account}/comments/'):
        if i == 0:
            ig_bbva_comments = pd.read_csv(f'dataset/{account}/comments/{csv_name}')
        else:
            ig_bbva_new_comments = pd.read_csv(f'dataset/{account}/comments/{csv_name}')
            ig_bbva_comments = ig_bbva_comments.append(ig_bbva_new_comments, ignore_index=True)
        i += 1
    ig_bbva_comments = ig_bbva_comments.drop_duplicates('text')
    ig_bbva_comments['text'] = ig_bbva_comments['text'].map(lambda x: re.sub(r'[^\w\s]', '', x))
    ig_bbva_comments = ig_bbva_comments.drop(ig_bbva_comments[ig_bbva_comments['text'] == ''].index)
    ig_bbva_comments.to_csv(f'dataset/{account}/{account}_comments.csv')
    i = 0

# %%
i = 0
for account in accounts:
    for csv_name in os.listdir(f'dataset/{account}/comments/'):
        if i == 0:
            ig_bbva_comments = pd.read_csv(f'dataset/{account}/comments/{csv_name}')
        else:
            ig_bbva_new_comments = pd.read_csv(f'dataset/{account}/comments/{csv_name}')
            ig_bbva_comments = ig_bbva_comments.append(ig_bbva_new_comments, ignore_index=True)
        i += 1
ig_bbva_comments = ig_bbva_comments.drop_duplicates('text')
ig_bbva_comments.to_csv('./dataset/bbva_comments.csv')
len(ig_bbva_comments)
# Out:
# 3407

# %%
i = 0
for account in accounts:
    for csv_name in os.listdir(f'dataset/{account}/likers/'):
        if i == 0:
            ig_bbva_likers = pd.read_csv(f'dataset/{account}/likers/{csv_name}')
        else:
            ig_bbva_new_likers = pd.read_csv(f'dataset/{account}/likers/{csv_name}')
            ig_bbva_likers = ig_bbva_likers.append(ig_bbva_new_likers, ignore_index=True)
        i += 1
    ig_bbva_likers = ig_bbva_likers.drop_duplicates('username')
    ig_bbva_likers.to_csv(f'dataset/{account}/{account}_likers.csv')
    i = 0

# %%
i = 0
for account in accounts:
    for csv_name in os.listdir(f'dataset/{account}/likers/'):
        if i == 0:
            ig_bbva_likers = pd.read_csv(f'dataset/{account}/likers/{csv_name}')
        else:
            ig_bbva_new_likers = pd.read_csv(f'dataset/{account}/likers/{csv_name}')
            ig_bbva_likers = ig_bbva_likers.append(ig_bbva_new_likers, ignore_index=True)
        i += 1
ig_bbva_likers = ig_bbva_likers.drop_duplicates('username')
ig_bbva_likers.to_csv('./dataset/bbva_likers.csv')

# %%
ig_bbva_comments = pd.read_csv('../../data/instagram/bbva_comments.csv', index_col=[0])
ig_bbva_likers = pd.read_csv('../../data/instagram/bbva_likers.csv', index_col=[0])

# %%
len(ig_bbva_comments)
# Out:
# 3407

# %%
len(ig_bbva_likers)
# Out:
# 7323

# %%
labels = {
    '__label__0': 'neg',
    '__label__1': 'pos'
}
pd.read_csv('pred.csv')['labels'].map(lambda x: labels[x])
# Out:
# 0       pos
# 1       neg
# 2       neg
# 3       pos
# 4       neg
#        ...
# 3402    neg
# 3403    neg
# 3404    neg
# 3405    neg
# 3406    pos
# Name: labels, Length: 3407, dtype: object

# %%
import re 

with open('test.csv', 'w') as f:
    for comment in pd.read_csv('../../data/instagram/bbva_comments.csv', index_col=[0])['text']:
        f.write(re.sub(r'[^\w\s]', '',comment.replace('\n', '') + '\n'))

# %%
preds = pd.read_csv('test.csv')
preds['pred'] = pd.read_csv('pred.csv')['labels'].map(lambda x: labels[x])

# %%
preds[preds['pred'] == 'pos']
preds
# Out:
#                                                 comment pred
# 0     READ THIS YOU WILL BE KISSED ON THE NEAREST PO...  pos
# 1                                       Quiero todo eso  neg
# 2     Muy muy muy mal servicio con un problema en ca...  neg
# 3                                                FRAUDE  neg
# 4     SON BBVA INSEGUROS 3 VECES ME DEJARON PLANTADA...  pos
# ...                                                 ...  ...
# 3284  En vez de subir estas estupideces porque no se...  neg
# 3285  Desastre de banco pesomo servicio  no te puedo...  pos
# 3286  Despidan a todos los ineptos de sus empleados ...  pos
# 3287  A mí me cerraron arbitrariamente mí cuenta y n...  neg
# 3288  HACEME A MI UNA ENTREVISTA SI TENES HUEVOS BAN...  neg
#
# [3289 rows x 2 columns]

# %%
label_map = {
    'pos': '__label__1',
    'neg': '__label__0',
}
train_set = pd.DataFrame()
train_set['label'] = preds['pred'].map(lambda x: label_map[x])[:100]
train_set['comment'] = preds['comentario'][:1000]

# %%
train_set
# Out:
#          label                                            comment
# 0   __label__1  READ THIS YOU WILL BE KISSED ON THE NEAREST PO...
# 1   __label__0                                    Quiero todo eso
# 2   __label__0  Muy muy muy mal servicio con un problema en ca...
# 3   __label__1                                             FRAUDE
# 4   __label__0  SON BBVA INSEGUROS 3 VECES ME DEJARON PLANTADA...
# ..         ...                                                ...
# 95  __label__1                                          iza_lucro
# 96  __label__1                                         charensebi
# 97  __label__1                                 mariajosealzugaray
# 98  __label__1                                   mariliacaraballo
# 99  __label__1                                       pablonoble31
#
# [100 rows x 2 columns]

# %%
train_set = pd.read_csv('train.csv', index_col=[0], sep=',')
train_set['comment'] = train_set['comment'].map(lambda x: str(x))
train_set
# Out:
#                                                       comment
# label
# __label__0   Cordobés porque me la complicaste con el coseno
# __label__1  Se imaginan a los chicos agradeciendo por el p...
# __label__0                                      Tengo fiebre
# __label__1  Eclesiastes4912  Siempre promesa   httpstcoXbr...
# __label__0                           sooooyderiver dame bola
# ...                                                       ...
# __label__1                           Y ahora no podré dormir
# __label__0  una crema para la cara me dio alergia en la ca...
# __label__1  En la Boca   Estadio Boca Juniors httpstco8Qds...
# __label__0                               Jajaja soy un cagon
# __label__1  Goooooooooooool La concha de la lora  Vamos Me...
#
# [109955 rows x 1 columns]

# %%
clean_comments = []
for comment in train_set['comment']:
    #print(comment)
    comment = comment.replace('\n', '')
    comment = comment.replace('__label__0', '0')
    comment = comment.replace('__label__1', '1')
    clean_comments.append(re.sub(r'[^\w\s]', '',comment))

# %%
train_set['comment'] = clean_comments

# %%
train_set.to_csv('/home/ivanovsky/git/fastText-0.9.2/data/train.csv')
train_set.to_csv('train.csv')
